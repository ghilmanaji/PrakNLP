# %% [markdown]
# Nama : Ghilman Farhani Putra Aji
#
# NIM : 20110006

# %% [markdown]
# Disini saya akan menggunakan library google play scraper untuk mendapatkan data aplikasi satu sehat
#
# Langkah pertama adalah dengan mengimport semua library yang akan dibutuhkan

# %%
from google_play_scraper import Sort, reviews
from google_play_scraper import app
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# kemudian, saya jalankan fungsi pada library google play scraper dengan memasukan variabel
#
# kode nama aplikasi satu sehat
#
# dengan bahasa indonesia
#
# dan negara indonesia
#
# kemudian saya sorting sesuai dengan yang terbaru
#
# dengan jumlah data 1.000
#
# kemudian untuk filter score yang diberikan adalah none(maksudnya adalah mengikutkan semua score yang ada didalam aplikasi tersebut)

# %%
result, continuation_token = reviews(
    "com.telkom.tracencare",
    lang='id',
    country='id',
    sort=Sort.NEWEST,
    count=1000,
    filter_score_with=None
)

# %% [markdown]
# kemudian data yang diperoleh yang tadinya berbentuk array saya ubah menjadi data frame

# %%
data=pd.DataFrame(np.array(result),columns=["review"])
data=data.join(pd.DataFrame(data.pop("review").tolist()))

# %%
data
# Out:
#                                  reviewId          userName  \
# 0    a2e46c13-4c64-4c54-b222-f82af4f56727        Bagus arif
# 1    431290b8-d911-41fc-90b1-9258f8481d80         Yuki Rose
# 2    7a84ad6e-9b03-4c40-a454-c46eabb12585  Ricky Nandhika09
# 3    a8e11c76-d899-4f75-8a76-e9ad13858872              Iwan
# 4    0fa8e343-5fe4-4491-9c89-125f2a5d633d    Kusnanto Nanto
# ..                                    ...               ...
# 995  fdb98200-f928-41b2-bbe8-7fd103ef6feb      Nur Kholifah
# 996  b310c313-408a-4294-a529-f4912b078f09  Elshi Pelgatasya
# 997  3ec0042d-dbc6-445c-ab9b-b4cf88a20eb8      Arief Rahman
# 998  5a51074d-6e1a-450d-8992-83fe21fa5e8e        Syahdee 74
# 999  803cd34c-d442-4cff-9d1e-cea5a1344279     Nirvana Nuban
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/a/ACg8oc...
# 1    https://play-lh.googleusercontent.com/a-/ALV-U...
# 2    https://play-lh.googleusercontent.com/a-/ALV-U...
# ...

# %% [markdown]
# kemudian saya export data yang diperoleh tadi kedalam bentuk csv

# %%
data.to_csv("dataset_komentar_satusehat.csv")
